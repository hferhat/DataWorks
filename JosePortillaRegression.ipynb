# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.lmplot('total_bill','tip',data=tips)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,
              scatter_kws={'marker':'o','color':'red'},
              line_kws= {'linewidth':1,'color':'blue'})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,order = 4,
              scatter_kws={'marker':'o','color':'red'},
              line_kws= {'linewidth':1,'color':'blue'})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,fit_reg=False)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pect'] = 100*tips['tip']/tips['total_bill']

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pect
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
sns.histplot(tips['size'])
# Out:
# <AxesSubplot:xlabel='size', ylabel='Count'>

# %%
sns.lmplot(x='size',y='tip_pect',data=tips)

# %%
sns.boxplot(x='size',y='tip_pect',data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip_pect'>

# %%
for i in :
    print(i)
# Out:
# 0.0
# 0.1
# 0.2
# 0.30000000000000004
# 0.4

# %%
for i in np.arange(0,0.5,0.1):    
    sns.lmplot(x='size',y='tip_pect',data=tips,x_jitter=i,)
    print(f"for x_jittter =",i)
    print("\n")
# Out:
# for x_jittter = 0.0
#
#
# for x_jittter = 0.1
#
#
# for x_jittter = 0.2
#
#
# for x_jittter = 0.30000000000000004
#
#
# for x_jittter = 0.4

# %%
sns.lmplot(x='size',y='tip_pect',data=tips,x_jitter=.4)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pect
# 0         16.99  1.01  Female     No   Sun  Dinner     2   5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3  16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3  16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2  13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4  14.680765
# ..          ...   ...     ...    ...   ...     ...   ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2   9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2  15.974441
#
# [244 rows x 8 columns]

# %%
sns.lmplot(x='total_bill',y='tip_pect',hue='sex',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip_pect',hue='sex',data=tips,markers=['x','o'])

# %%
sns.lmplot(x='total_bill',y='tip_pect',hue='day',data=tips)

# %%
sns.regplot(x='total_bill',y='tip_pect',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip_pect'>

# %%
# reg_plot can be added to existing axes without modifying anything in the figure

# Create figure with 2 subplots
fig, (axis1,axis2) = plt.subplots(1,2,sharey =True)

sns.regplot("total_bill","tip_pect",tips,ax=axis1)
sns.violinplot(tips['tip_pect'],tips['size'],colors='Reds',ax=axis2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip_pect', ylabel='size'>
